# %% [markdown]
# <a href="https://colab.research.google.com/github/GauravJain448/python/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1 — Variables

# %%
name="Gaurav Jain"
age=36
salary=10000

print(name)
print(age)
print(salary)
# Out:
# Gaurav Jain
# 36
# 10000

# %%
city="Faridabad"
aiTools="Chat GPT"
experience=15

print(city)
print(aiTools)
print(experience)
# Out:
# Faridabad
# Chat GPT
# 15

# %% [markdown]
# # Part 2 — Data Types

# %%
name="Gaurav Jain"
print(type(name))

number=10
print(type(number))

price=99.99
print(type(price))

is_valid=True
print(type(is_valid))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# # Part 3 — Lists

# %%
ai_tools=["Chat GPT", "Gemini", "Claude"]
print(ai_tools)

print(ai_tools[2])

ai_tools.append("Copilot")
print(ai_tools)
# Out:
# ['Chat GPT', 'Gemini', 'Claude']
# Claude
# ['Chat GPT', 'Gemini', 'Claude', 'Copilot']

# %%
mobiles_app=["facebook", "instagram", "whatsapp"]
print(mobiles_app)
print(mobiles_app[0])

mobiles_app.append("zerodha")
print(mobiles_app)
# Out:
# ['facebook', 'instagram', 'whatsapp']
# facebook
# ['facebook', 'instagram', 'whatsapp', 'zerodha']

# %% [markdown]
# # Mini Project — Mood Detector

# %%
text=input("Enter text:")

if "happy" in text:
 print("Mood is happy")
if "sad" in text:
  print("Mood is sad")
else:
 print("Mood is neutral")
# Out:
# Enter text:sad
# Mood is sad

# %% [markdown]
# # AI Practice

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")

texts = [
    "I love AI",
    "The build failed",
    "Python is amazing"
]

results = classifier(texts)

for result in results:
    print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# ...

# %%
from transformers import pipeline

classifier= pipeline("sentiment-analysis")

texts=[
    "I hate bugs in my room"
]

results= classifier(texts)

for result in results:
  print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# {'label': 'NEGATIVE', 'score': 0.9985270500183105}

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")

def analyzer(text):
  result = classifier(text)
  return result

print(analyzer("Apple fruit is black"))
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# [{'label': 'NEGATIVE', 'score': 0.9834325909614563}]

# %%
from sklearn.linear_model import LinearRegression

# Training data
house_sizes = [
    [1000],
    [1500],
    [2000],
    [2500]
]

house_prices = [
    50,
    75,
    100,
    125
]

# Create model
model = LinearRegression()

# Train model
model.fit(house_sizes, house_prices)

# Predict new value
prediction = model.predict([[1800]])

print("Predicted price:", prediction)
# Out:
# Predicted price: [90.]

# %%
from sklearn.linear_model import LinearRegression

# Training data
house_sizes = [
    [1000],
    [1500],
    [2000],
    [2500],
    [3000]
]

house_prices = [
    50,
    75,
    100,
    125,
    150
]

# create model
model = LinearRegression()

# Train model

model.fit(house_sizes, house_prices)

# Prdicct new value

prediction = model.predict([[3000]])
print("Predicted price:", prediction)

prediction = model.predict([[1200]])

print("Predicted price:", prediction)
# Out:
# Predicted price: [150.]
# Predicted price: [60.]

# %%
import pandas as pd

data = {
    "Name": ["John", "Mike", "Sarah"],
    "Age": [25, 35, 40],
    "Salary": [50000, 80000, 100000]
}

df = pd.DataFrame(data)

#print(df)

#print(df["Name"])

#print(df[df["Age"]>30])

#print("Info:", df.info())
print("describe:",df.describe())
# Out:
# describe:              Age         Salary
# count   3.000000       3.000000
# mean   33.333333   76666.666667
# std     7.637626   25166.114784
# min    25.000000   50000.000000
# 25%    30.000000   65000.000000
# 50%    35.000000   80000.000000
# 75%    37.500000   90000.000000
# max    40.000000  100000.000000

# %%
import pandas as pd

df = pd.read_csv("sample_data/employees.csv")

print(df)
# Out:
#     Name  Age  Salary
# 0   Jhon   25   50000
# 1   Mike   35   80000
# 2  Sarah   40  100000
# 3   Alex   28   45000
